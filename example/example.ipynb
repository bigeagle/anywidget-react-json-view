# %%
from rjv_anywidget import JsonWidget

data = {
    "_id": "68f765994e1beb5350077a25",
    "index": 0,
    "guid": "c05a925c-c4f0-496b-951f-2e15fa357711",
    "isActive": False,
    "balance": "$2,600.03",
    "picture": "http://placehold.it/32x32",
    "age": 33,
    "eyeColor": "blue",
    "name": "Allyson Hopkins",
    "gender": "female",
    "company": "PROWASTE",
    "email": "allysonhopkins@prowaste.com",
    "phone": "+1 (842) 473-2045",
    "address": "904 Manhattan Avenue, Eastvale, Hawaii, 5356",
    "about": "Ut ex est consequat qui anim elit voluptate fugiat dolor. \nSit enim aliqua minim ullamco. \nDeserunt reprehenderit amet aliqua cillum do. Irure aliquip sint do elit non anim Lorem labore. In laborum aute cillum labore elit dolor. Enim commodo nostrud cillum ex mollit ipsum ad quis et nostrud mollit.\r\n",
    "registered": "2022-08-28T05:26:08 -08:00",
    "latitude": -73.415044,
    "longitude": 74.613609,
    "tags": [
      "aute",
      "reprehenderit",
      "exercitation",
      "est",
      "dolor",
      "adipisicing",
      "laboris"
    ],
    "friends": [
      {
        "id": 0,
        "name": "Concetta Sutton"
      },
      {
        "id": 1,
        "name": "Merrill Wise"
      },
      {
        "id": 2,
        "name": "Winifred Sparks"
      }
    ],
    "greeting": "Hello, Allyson Hopkins! You have 7 unread messages.",
    "favoriteFruit": "strawberry"
  }

JsonWidget(data, theme='monokai')
# Out:
# JsonWidget(json_data={'_id': '68f765994e1beb5350077a25', 'index': 0, 'guid': 'c05a925c-c4f0-496b-951f-2e15fa35…
